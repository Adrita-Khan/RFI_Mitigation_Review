# %%
pip install squarify

# %%
# Treemap Visualization

import matplotlib.pyplot as plt
import squarify
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

# Data
categories = ['CNN', 'Deep CNN', 'Random Forest', 'SVM', 'K-Means', 'SOM', 'CNN Autoencoder']
values = [50, 30, 10, 20, 15, 25, 5]

# Sort the data in descending order
sorted_indices = sorted(range(len(values)), key=lambda i: values[i], reverse=True)
categories = [categories[i] for i in sorted_indices]
values = [values[i] for i in sorted_indices]

# Calculate percentages for labels
total = sum(values)
percentages = [f"{(value / total) * 100:.1f}%" for value in values]

# Combine categories with percentages
labels = [f"{cat}\n{perc}" for cat, perc in zip(categories, percentages)]

# Color Palette
# Use a colormap to generate distinct colors
cmap = plt.cm.get_cmap('Set3', len(categories))
colors = [cmap(i) for i in range(len(categories))]

# Create the treemap
plt.figure(figsize=(14, 9))
ax = plt.gca()
squarify.plot(
    sizes=values,
    label=labels,
    color=colors,
    alpha=0.9,
    edgecolor='white',
    linewidth=2,
    ax=ax
)

# Title with enhanced styling
plt.title(
    'Top Seven Most Commonly Used Machine Learning Methodologies in Radio Astronomy',
    fontsize=18,
    fontweight='bold',
    pad=20
)

# Remove axes
plt.axis('off')

# Add annotations or subtitle if needed
# plt.text(0.5, 0.95, 'Data Source: Your Data Source', horizontalalignment='center', fontsize=12, transform=ax.transAxes)

# Add a legend (optional)
# Create custom patches for the legend
patches = [mpatches.Patch(color=colors[i], label=f"{categories[i]} ({percentages[i]})") for i in range(len(categories))]
plt.legend(
    handles=patches,
    loc='upper left',
    bbox_to_anchor=(1, 1),
    fontsize=12,
    title="Categories",
    title_fontsize=14,
    frameon=False
)

# Adjust layout for better spacing
plt.tight_layout()

# Add a subtle background color
plt.gca().set_facecolor('#f9f9f9')

# Display the treemap
plt.show()
# Out:
# <ipython-input-2-158d1cf9bbe4>:26: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Set3', len(categories))

# %%
# Treemap Visualization

import matplotlib.pyplot as plt
import squarify
import matplotlib.colors as mcolors

# Data
categories = ['CNN', 'Deep CNN', 'Random Forest', 'SVM', 'K-Means', 'SOM', 'CNN Autoencoder']
values = [50, 30, 10, 20, 15, 25, 5]

# Calculate percentages for labels
total = sum(values)
percentages = [f"{(value / total) * 100:.1f}%" for value in values]

# Combine categories with percentages
labels = [f"{cat}\n{perc}" for cat, perc in zip(categories, percentages)]

# Color Palette
# Use a colormap to generate distinct colors
cmap = plt.cm.get_cmap('Set3', len(categories))
colors = [cmap(i) for i in range(len(categories))]

# Create the treemap
plt.figure(figsize=(12, 8))
squarify.plot(
    sizes=values,
    label=labels,
    color=colors,
    alpha=0.8,
    edgecolor='white',
    linewidth=2
)

# Title with enhanced styling
plt.title(
    'Top Seven Most Commonly Used Machine Learning Methodologies in Radio Astronomy',
    fontsize=16,
    fontweight='bold'
)

# Remove axes
plt.axis('off')

# Add a legend (optional)
# Create custom patches for the legend
import matplotlib.patches as mpatches

patches = [mpatches.Patch(color=colors[i], label=f"{categories[i]} ({percentages[i]})") for i in range(len(categories))]
plt.legend(
    handles=patches,
    loc='upper right',
    bbox_to_anchor=(1.15, 1),
    fontsize=12,
    title="Categories",
    title_fontsize=14
)

# Adjust layout for better spacing
plt.tight_layout()

# Display the treemap
plt.show()
# Out:
# <ipython-input-3-f7120a63c64d>:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Set3', len(categories))
